# %% [markdown]
# # Hotel Demand Analysis
#
# Data Cleaning and Exploration

# %%
import pandas as pd

# %%
df=pd.read_csv('hotel_bookings_cleaned.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# Sort and filter columns

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hotel_bookings=df[['hotel', 'is_canceled', 'lead_time','reservation_status_date', 'stays_in_weekend_nights',
       'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
       'country', 'market_segment', 'distribution_channel',
       'is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'booking_changes', 'customer_type', 'adr',
       'reservation_status',
       ]]

# %%
hotel_bookings.head()
# Out:
#           hotel  is_canceled  lead_time reservation_status_date  \
# 0  Resort Hotel            0        342              2015-07-01
# 1  Resort Hotel            0        737              2015-07-01
# 2  Resort Hotel            0          7              2015-07-02
# 3  Resort Hotel            0         13              2015-07-02
# 4  Resort Hotel            0         14              2015-07-03
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# 1                        0                     0       2       0.0       0
# 2                        0                     1       1       0.0       0
# 3                        0                     1       1       0.0       0
# 4                        0                     2       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# ...

# %%
hotel_bookings.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# reservation_status_date            object
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# customer_type                      object
# adr                               float64
# reservation_status                 object
# dtype: object

# %%
hotel_bookings['reservation_status_date']=hotel_bookings['reservation_status_date'].astype('datetime64[ns]')
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_3640\545529353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bookings['reservation_status_date']=hotel_bookings['reservation_status_date'].astype('datetime64[ns]')

# %%
hotel_bookings.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# reservation_status_date           datetime64[ns]
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# booking_changes                            int64
# customer_type                             object
# adr                                      float64
# ...

# %%
hotel_bookings.isna().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# reservation_status_date             0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# booking_changes                     0
# customer_type                       0
# adr                                 0
# reservation_status                  0
# dtype: int64

# %%
hotel_bookings[hotel_bookings['country'].isna()]
# Out:
#                hotel  is_canceled  lead_time reservation_status_date  \
# 30      Resort Hotel            0        118              2015-07-15
# 4127    Resort Hotel            1          0              2016-02-15
# 7092    Resort Hotel            1          8              2016-07-20
# 7860    Resort Hotel            1         39              2016-07-22
# 8779    Resort Hotel            1          0              2016-10-13
# ...              ...          ...        ...                     ...
# 65908     City Hotel            1          0              2017-04-10
# 65909     City Hotel            1          0              2017-04-10
# 65910     City Hotel            1          0              2017-04-10
# 80830     City Hotel            0          4              2015-11-26
# 101488    City Hotel            0          1              2016-11-17
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
PN =df[df['is_canceled']== 1]
PN
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 110280    City Hotel            1        132               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
hotel_bookings['country'].fillna('Not Supplied', inplace=True)
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_3640\2805530227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bookings['country'].fillna('Not Supplied', inplace=True)

# %%
hotel_bookings.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# reservation_status_date           0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          4
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# customer_type                     0
# adr                               0
# reservation_status                0
# dtype: int64

# %%
hotel_bookings['children'].fillna( 0 ,inplace=True)
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_3640\4129883758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bookings['children'].fillna( 0 ,inplace=True)

# %%
hotel_bookings.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# reservation_status_date           0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# customer_type                     0
# adr                               0
# reservation_status                0
# dtype: int64

# %%
hotel_bookings.head()
# Out:
#           hotel  is_canceled  lead_time reservation_status_date  \
# 0  Resort Hotel            0        342              2015-07-01
# 1  Resort Hotel            0        737              2015-07-01
# 2  Resort Hotel            0          7              2015-07-02
# 3  Resort Hotel            0         13              2015-07-02
# 4  Resort Hotel            0         14              2015-07-03
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# 1                        0                     0       2       0.0       0
# 2                        0                     1       1       0.0       0
# 3                        0                     1       1       0.0       0
# 4                        0                     2       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# ...

# %%
#hotel_bookings.to_csv('HotelBookingsAnalysis.csv',index=False)
